# %%
include("../src/data_gen.jl")
# Out:
# get_data

# %%
function sample_10_functions()
    for i=1:10
        println(function_prior())
    end
end;

fns = sample_10_functions()
# Out:
# Mul(Sin(0.3383839722218794, 1.05226604566528), Sin(0.811675735932668, 0.7931039465885388), 3)
# Mul(Lin(-0.08276008332724727, 0.5836498187096683), Lin(-0.6034715842428604, 0.3323516764375679), 3)
# Sin(1.4470607581556205, 1.6031844395917854)
# Sin(1.9361805277192312, 0.16577365004228595)
# Lin(-0.8990244113758032, 0.25037142958826064)
# Lin(-0.8923883257691512, 0.4132155435837084)
# Lin(0.3387994986993723, 0.24565796588141597)
# Mul(Sin(1.2793896251222086, 0.8311531257779619), Lin(-0.037227194991203305, 0.5752475354904331), 3)
# Lin(-0.352444375062571, 0.12544515363876885)
# Mul(Mul(Add(Lin(0.04170213330062977, 0.9244971081447195), Mul(Lin(0.298225325178445, 0.9494417967324017), Lin(-0.20971541316185172, 0.9207922028944743), 3), 5), Lin(0.6653516344538692, 0.8763407643091785), 7), Lin(0.2772053505758887, 0.6389693776204995), 9)

# %%
using Plots

fn = function_prior();

# Generate and plot some data
xs, ys, fn, (xmin_orig, xmax_orig) = get_data(fn, 100, noise=0.2)
println("Function: ", fn)
println("Original x range: [$xmin_orig, $xmax_orig]")
scatter(xs, ys, xlims=(0, 1), ylims=(0, 1), 
        title="Sampled Function Data (normalized)", label="data points", color="black")
# Out:
# Function: Mul(Sin(1.1022399338286466, 1.6530219587685007), Lin(0.7425727977768819, 0.9865698040315917), 3)
# Original x range: [-1.808594654646519, 1.0463184091537743]
