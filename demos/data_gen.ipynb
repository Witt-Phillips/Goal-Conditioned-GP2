# %%
include("../src/data_gen.jl")
# Out:
# get_data

# %%
function sample_10_functions()
    for i=1:10
        println(function_prior())
    end
end;

fns = sample_10_functions()
# Out:
# Lin(-0.7114630222228173, 0.9370799140846442)
# Lin(0.6823476092029626, 0.918484905422831)
# Add(Sin(1.5902022032058276, 1.740522089551986), Add(Mul(Sin(0.6882148353199722, 0.3351298043583393), Lin(0.9362781295869615, 0.8403078699268743), 3), Sin(1.0245524080129962, 0.3970605464696396), 5), 7)
# Lin(-0.8743701511690778, 0.7057619242685046)
# Sin(1.310382339400841, 0.12623500741732363)
# Lin(-0.03701371870424364, 0.0663194680251924)
# Sin(1.0379364086616203, 0.7091236915729207)
# Add(Sin(1.3504000011303476, 1.2796698619532993), Lin(-0.22375826324438508, 0.01268108645897481), 3)
# Mul(Mul(Add(Add(Lin(0.20739154380687874, 0.4600468665512588), Lin(0.011392694069584097, 0.9894078677472861), 3), Sin(1.3098057694370904, 0.702976717762682), 5), Add(Add(Sin(0.4786169292899428, 0.15285689432187635), Lin(-0.3263436176147909, 0.3286932555264007), 3), Sin(1.8002235945820118, 1.7708700506507389), 5), 11), Mul(Lin(0.39472900448905013, 0.14557587736740896), Add(Lin(-0.21407206877740448, 0.6075251254064747), Sin(0.9504464457937476, 0.531323257715742), 3), 5), 17)
# Add(Add(Lin(0.06099544164068749, 0.6257536142761604), Add(Mul(Sin(0.4719438389502525, 1.5805249096262362), Lin(0.49464727383500473, 0.16954567534183929), 3), Add(Mul(Lin(0.8362673904349585, 0.9160493726571995), Lin(-0.1548625425464405, 0.8797770713735781), 3), Sin(1.4606712816951457, 0.6141065797844589), 5), 9), 11), Lin(-0.17728711844909473, 0.9881830085416045), 13)

# %%
using Plots

fn = function_prior();

# Generate and plot some data
xs, ys, fn, (xmin_orig, xmax_orig) = get_data(fn, 100)
println("Function: ", fn)
println("Original x range: [$xmin_orig, $xmax_orig]")
scatter(xs, ys, xlims=(0, 1), ylims=(0, 1), 
        title="Sampled Function Data (normalized)", label="data points", color="black")
# Out:
# Function: Add(Lin(-0.40135371707301015, 0.5899408156575395), Mul(Mul(Sin(0.63016064168518, 1.0249869533362939), Lin(0.7247847181831204, 0.47636777255732576), 3), Sin(0.22881386937418888, 1.4098749789971596), 5), 7)
# Original x range: [-0.9173665292069395, 0.8979359464610686]
