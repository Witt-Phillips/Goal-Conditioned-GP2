# %%
include("../src/data_gen.jl")
# Out:
# get_data

# %%
function sample_10_functions()
    for i=1:10
        println(function_prior())
    end
end;

fns = sample_10_functions()
# Out:
# Add(Sin(2.2129257535533426, 0.8248899099612297), Lin(1.053397028749865, 4.173386970885513), 3)
# Mul(Add(Add(Add(Mul(Sin(2.3398830137137354, 0.5248550054806849), Lin(-2.0708166488242776, -1.792161144926526), 3), Sin(3.041746457368466, 1.9718882860095228), 5), Add(Lin(-2.4378290651186374, 0.3957469396830602), Sin(2.0317465762414852, 1.4556020985035258), 3), 9), Sin(4.76092144594429, 2.925565082729072), 11), Lin(-4.434341836611111, 4.509330262955734), 13)
# Add(Sin(2.238570117097992, 2.073522011829909), Sin(4.9233662417242, 4.444517116158941), 3)
# Add(Mul(Add(Sin(2.067014927193254, 3.7764426027120277), Add(Lin(-1.4107415758123167, -1.5637615828270723), Lin(-1.9153851052705786, -2.949940583787747), 3), 5), Lin(-4.00644338919257, -4.152309836586321), 7), Sin(2.9444923849807365, 3.896298897454562), 9)
# Mul(Mul(Lin(0.3114434799701735, -1.4305213146177298), Sin(3.8023155216717965, 4.091920724977864), 3), Lin(4.369699335442682, -2.1211819195697643), 5)
# Lin(0.7265808294046945, 2.5090994093209273)
# Sin(3.806544899505972, 4.205631523132657)
# Sin(3.930037504475835, 0.6578990641262552)
# Mul(Sin(1.6877626148839748, 1.280292588632217), Mul(Sin(3.141509431823568, 2.511427406749833), Mul(Sin(4.833698834144296, 1.0867454289517986), Mul(Mul(Sin(0.8103915560808947, 1.3735831506564584), Mul(Add(Sin(4.685567184290516, 0.6193567477564421), Lin(-3.4583290954319934, 1.7516958674438143), 3), Sin(3.9310202153846063, 1.6822776806098996), 5), 7), Sin(1.716594395523697, 3.9781053136421547), 9), 11), 13), 15)
# Add(Lin(4.581069757455607, -4.52811086238162), Add(Mul(Add(Mul(Add(Add(Sin(2.93242128056883, 3.1327744575694125), Lin(-4.390245164182259, 0.2251689536562287), 3), Sin(0.52835489903249, 2.8007495019093986), 5), Sin(0.6970393748977709, 1.3850683552941065), 7), Add(Mul(Sin(3.9016769783906025, 2.2967649643070462), Sin(2.609101706868447, 4.25099880666521), 3), Add(Sin(3.103949531693463, 0.8502828966678452), Sin(2.5748035730318333, 4.087431321686646), 3), 7), 15), Mul(Lin(2.484806340471958, 1.2215809682964966), Lin(1.8593575836884444, 4.912418655904558), 3), 19), Lin(-4.324692585084609, -1.7545863323616206), 21), 23)

# %%
using Plots

fn = function_prior();

# Generate and plot some data
xs, ys, fn, (xmin_orig, xmax_orig) = get_data(fn, 100)
println("Function: ", fn)
println("Original x range: [$xmin_orig, $xmax_orig]")
scatter(xs, ys, xlims=(0, 1), ylims=(0, 1), 
        title="Sampled Function Data (normalized)", label="data points", color="black")
# Out:
# Function: Add(Lin(0.3386807166008068, 0.9584126883774773), Add(Mul(Lin(0.40271630207419795, 0.6262672124098735), Add(Mul(Lin(0.9928880097052284, 0.1939036735820121), Add(Lin(0.5665860918220422, 0.3268991396537122), Mul(Lin(0.6643573683173385, 0.15541717452511317), Sin(0.11105058326062589, 0.23968428440750947), 3), 5), 7), Sin(0.9140646304912609, 0.8323725717591153), 9), 11), Mul(Sin(1.0269641848286766, 1.2133419218483625), Mul(Sin(1.6550874578845391, 0.36333623000150594), Lin(-0.9161839553908173, 0.7498669375916246), 3), 5), 17), 19)
# Original x range: [0.9767736644130229, 3.9770125735833157]
