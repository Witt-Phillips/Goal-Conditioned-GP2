# %%
include("../src/data_gen.jl")
# Out:
# list_saved_runs

# %%
function sample_10_functions()
    for i=1:10
        println(function_prior())
    end
end;

fns = sample_10_functions()
# Out:
# Sin(1.3980228192978321, 0.22914353284914224)
# Mul(Sin(0.9691595773736473, 0.19273794048193177), Add(Sin(0.8045692153567475, 0.40998495370821353), Sin(0.22395825464371066, 0.26789786258612913), 3), 5)
# Sin(1.8549049814943983, 0.21817620167923807)
# Add(Sin(1.7043665643369004, 0.4695003094785195), Lin(0.38660746595105766, 0.422084392277123), 3)
# Lin(0.2160347291269149, 0.36378597101267307)
# Mul(Add(Sin(0.6361361409059166, 0.1812830158572704), Lin(-0.705809220786668, 0.6484348102212941), 3), Add(Sin(0.8030042982682065, 0.45445162166649233), Sin(1.5343259584077973, 0.38500423318934585), 3), 7)
# Add(Sin(1.55301334406592, 0.18976407760899588), Sin(0.8005926239394778, 0.10224051654163807), 3)
# Sin(0.861229590916079, 0.14810468969132395)
# Sin(1.9524847446186422, 0.31503340048150813)
# Lin(0.9258177632176059, 0.5152907030317555)

# %%
using Plots

fn = function_prior();

# xs, ys, fn, (xmin_orig, xmax_orig) = get_data(fn, 100)
xs, ys, _, _ = load_data_run("/Users/witt/work/Goal-Conditioned-GP2/demos/data/run_3.json")

println("Function: ", fn)
println("Original x range: [$xmin_orig, $xmax_orig]")
scatter(xs, ys, xlims=(0, 1), ylims=(0, 1), 
        title="Sampled Function Data (normalized)", label="data points", color="black")
# Out:
# Loaded data run: 3
#   Saved at: 2025-12-10T14:14:43.385
# Function: Mul(Mul(Add(Add(Mul(Lin(-0.719178591332827, 0.18289562335817944), Add(Add(Sin(0.9823851989027147, 0.22580620440027604), Sin(1.8216199704365925, 0.26822988522678337), 3), Add(Lin(-0.9468543510303664, 0.4461303433798256), Mul(Mul(Sin(0.1954157971172396, 0.3393703911400971), Sin(1.8634931926206986, 0.0682725849799349), 3), Mul(Sin(0.12657784185051635, 0.32891668983954336), Mul(Sin(1.483709077832447, 0.13863918223591906), Sin(1.5250831847625472, 0.2566897699945655), 3), 5), 9), 11), 15), 17), Mul(Lin(0.3323605331202233, 0.04569498299571961), Add(Add(Sin(1.1498253394961733, 0.08584419396439366), Mul(Sin(0.6406496390248444, 0.4436401794483241), Sin(1.9116808905687468, 0.12998209076790274), 3), 5), Lin(0.7823722218230782, 0.5044122174324978), 7), 9), 27), Sin(0.8674064882608326, 0.32499697210171163), 29), Lin(-0.09952159123397664, 0.7473592917509826), 31), Mul(Add(Lin(-0.7941246502055634, 0.9253717589983752), Sin(0.3305207967686773, 0.3596988988194869), 3), Sin(1.5721993984212967, 0.383881719227697), 5), 37)
# Original x range: [0.28971399446743273, 1.3530246532487014]

# %%
save_data_run(xs, ys, fn, (xmin_orig, xmax_orig), "8")
# Out:
# Saved data run to: data/run_8.json
# "data/run_8.json"
